# %%
import os

import pandas as pd
import numpy as np
import mne
import h5py
from dataclasses import dataclass

from rembler.utils.dataset_utils import split_train_test
from rembler.utils.io_utils import aggregate_csvs, list_files_with_extension
from rembler.utils import sleep_utils as su

# %%
full.head()
# Out:
#   sleep  start   stop  activity context subject   session day
# 0     A      0   5000  0.091589     AAA   MPSD4  Baseline   1
# 1     A   5000  10000  0.011654    AAAX   MPSD4  Baseline   1
# 2     A  10000  15000  1.001923   AAAXA   MPSD4  Baseline   1
# 3     X  15000  20000  4.275597   AAXAA   MPSD4  Baseline   1
# 4     A  20000  25000  2.070143   AXAAA   MPSD4  Baseline   1

# %%
stage_matched.head()
# Out:
#   sleep  start   stop  activity context subject   session day
# 0     R  55000  60000  0.017417   SSRRR   MPSD1  Baseline   1
# 1     R  60000  65000  0.017363   SRRRR   MPSD1  Baseline   1
# 2     R  65000  70000  0.017319   RRRRR   MPSD1  Baseline   1
# 3     R  70000  75000  0.017282   RRRRR   MPSD1  Baseline   1
# 4     R  75000  80000  0.017252   RRRRR   MPSD1  Baseline   1

# %%
final
# Out:
#       sleep     start      stop  activity context subject   session  day  \
# 0         S  34970000  34975000  0.015893   SSSSS   MPSD1  Baseline    1
# 1         R  16815000  16820000  0.004257   RRRRR   MPSD1  Baseline    1
# 2         R  35295000  35300000  0.039750   RRRAA   MPSD1  Baseline    1
# 3         A  39020000  39025000  1.003210   AAAAA   MPSD1  Baseline    1
# 4         A   8015000   8020000  2.472006   AAAAX   MPSD1  Baseline    1
# ...     ...       ...       ...       ...     ...     ...       ...  ...
# 17632     A  27190000  27195000  0.005248   AAAAA   MPSD9  Recovery  End
# 17633     R  35075000  35080000  0.010631   SSRRR   MPSD9  Recovery  End
# 17634     A  23830000  23835000  3.184113   AAAAA   MPSD9  Recovery  End
# 17635     A  37550000  37555000  0.081009   AAAAA   MPSD9  Recovery  End
# 17636     S  11220000  11225000  0.003216   SSSAS   MPSD9  Recovery  End
#
#         role
# 0      train
# 1      train
# 2      train
# 3      train
# 4      train
# ...      ...
# 17632   test
# 17633   test
# 17634   test
# 17635   test
# 17636   test
#
# [17637 rows x 9 columns]

# %%
df = pd.read_csv("data/full_sleep_stage_matched_train_test_split.csv")

# %%
file_components =df.loc[df["role"] == "train"][["subject", "session", "day"]].drop_duplicates(subset=["subject", "session"])

# %%
@dataclass
class Config:
    bout_length: float
    bout_context: float
    sample_rate: float
    causal: bool

config = Config(
    bout_length=10.0,
    bout_context=5.0,
    sample_rate=500.0,
    causal=False,
)

# %%
signals_to_extract = ["EEG", "EMG"]
path = os.path.join("/Volumes/DataCave/rembler_data/training_datasets", "5bout_context_non_causal.h5")

with h5py.File(path, "a") as f:
    for idx, row in file_components.iterrows():
        if row["session"] == "Baseline":
            edf_filename = os.path.join("/Volumes/DataCave/rembler_data/raw_edf", f"{row['subject']} {row['session']}.edf")
        else:
            edf_filename = os.path.join("/Volumes/DataCave/rembler_data/raw_edf", f"{row['subject']} {row['session']} {row['day']}.edf")
        # subset to rows relevant to this file
        df_sub = df.query(f"subject == '{row['subject']}' & session == '{row['session']}' & day == '{row['day']}'")
        # read the edf file
        edf_data = mne.io.read_raw_edf(edf_filename, preload=True, verbose="WARNING")
        signals = edf_data.get_data(signals_to_extract)
        leading_buffer, trailing_buffer = su.determine_buffering(
            config.bout_length, config.bout_context, config.sample_rate, config.causal
        )
        # loop over each row in the subset dataframe
        for idx, row in df_sub.iterrows():
            # extract the relevant signal segments
            bout_signals = su.get_bout_signal(signals, row, leading_buffer, trailing_buffer)
            # save the extracted segments to the HDF5 file
            for i, signal_type in enumerate(signals_to_extract):
                f.create_dataset(f"{row['bout_id']}/{signal_type.lower()}", data=bout_signals[i])
                f.flush()

# %%
# Out:
# 0
#   eeg: (25000,)
#   emg: (25000,)
# 1
#   eeg: (25000,)
#   emg: (25000,)
# 10
#   eeg: (25000,)
#   emg: (25000,)
# 100
#   eeg: (25000,)
#   emg: (25000,)
# 1000
#   eeg: (25000,)
#   emg: (25000,)
# 1001
#   eeg: (25000,)
#   emg: (25000,)
# 1002
#   eeg: (25000,)
#   emg: (25000,)
# 1003
#   eeg: (25000,)
#   emg: (25000,)
# 1004
#   eeg: (25000,)
#   emg: (25000,)
# 1005
#   eeg: (25000,)
#   emg: (25000,)
# 1006
#   eeg: (25000,)
#   emg: (25000,)
# 1007
#   eeg: (25000,)
#   emg: (25000,)
# 1008
#   eeg: (25000,)
#   emg: (25000,)
# 1009
#   eeg: (25000,)
#   emg: (25000,)
# 101
#   eeg: (25000,)
#   emg: (25000,)
# 1010
#   eeg: (25000,)
#   emg: (25000,)
# 1011
#   eeg: (25000,)
#   emg: (25000,)
# 1012
#   eeg: (25000,)
#   emg: (25000,)
# 1013
#   eeg: (25000,)
#   emg: (25000,)
# 1014
#   eeg: (25000,)
#   emg: (25000,)
# 1015
#   eeg: (25000,)
#   emg: (25000,)
# 1016
#   eeg: (25000,)
#   emg: (25000,)
# 1017
#   eeg: (25000,)
#   emg: (25000,)
# 1018
#   eeg: (25000,)
#   emg: (25000,)
# 1019
#   eeg: (25000,)
#   emg: (25000,)
# 102
#   eeg: (25000,)
#   emg: (25000,)
# 1020
#   eeg: (25000,)
#   emg: (25000,)
# 1021
#   eeg: (25000,)
#   emg: (25000,)
# 1022
#   eeg: (25000,)
#   emg: (25000,)
# 1023
#   eeg: (25000,)
#   emg: (25000,)
# 1024
#   eeg: (25000,)
#   emg: (25000,)
# 1025
#   eeg: (25000,)
#   emg: (25000,)
# 1026
#   eeg: (25000,)
#   emg: (25000,)
# 1027
#   eeg: (25000,)
#   emg: (25000,)
# 1028
#   eeg: (25000,)
#   emg: (25000,)
# 1029
#   eeg: (25000,)
#   emg: (25000,)
# 103
#   eeg: (25000,)
#   emg: (25000,)
# 1030
#   eeg: (25000,)
#   emg: (25000,)
# 1031
#   eeg: (25000,)
#   emg: (25000,)
# 104
#   eeg: (25000,)
#   emg: (25000,)
# 105
#   eeg: (25000,)
#   emg: (25000,)
# 106
#   eeg: (25000,)
#   emg: (25000,)
# 107
#   eeg: (25000,)
#   emg: (25000,)
# 108
#   eeg: (25000,)
#   emg: (25000,)
# 109
#   eeg: (25000,)
#   emg: (25000,)
# 11
#   eeg: (25000,)
#   emg: (25000,)
# 110
#   eeg: (25000,)
#   emg: (25000,)
# 111
#   eeg: (25000,)
#   emg: (25000,)
# 112
#   eeg: (25000,)
#   emg: (25000,)
# 113
#   eeg: (25000,)
#   emg: (25000,)
# 114
#   eeg: (25000,)
#   emg: (25000,)
# 115
#   eeg: (25000,)
#   emg: (25000,)
# 116
#   eeg: (25000,)
#   emg: (25000,)
# 117
#   eeg: (25000,)
#   emg: (25000,)
# 118
#   eeg: (25000,)
#   emg: (25000,)
# 119
#   eeg: (25000,)
#   emg: (25000,)
# 12
#   eeg: (25000,)
#   emg: (25000,)
# 120
#   eeg: (25000,)
#   emg: (25000,)
# 121
#   eeg: (25000,)
#   emg: (25000,)
# 122
#   eeg: (25000,)
#   emg: (25000,)
# 123
#   eeg: (25000,)
#   emg: (25000,)
# 124
#   eeg: (25000,)
#   emg: (25000,)
# 125
#   eeg: (25000,)
#   emg: (25000,)
# 126
#   eeg: (25000,)
#   emg: (25000,)
# 127
#   eeg: (25000,)
#   emg: (25000,)
# 128
#   eeg: (25000,)
#   emg: (25000,)
# 129
#   eeg: (25000,)
#   emg: (25000,)
# 13
#   eeg: (25000,)
#   emg: (25000,)
# 130
#   eeg: (25000,)
#   emg: (25000,)
# 131
#   eeg: (25000,)
#   emg: (25000,)
# 132
#   eeg: (25000,)
#   emg: (25000,)
# 133
#   eeg: (25000,)
#   emg: (25000,)
# 134
#   eeg: (25000,)
#   emg: (25000,)
# 135
#   eeg: (25000,)
#   emg: (25000,)
# 136
#   eeg: (25000,)
#   emg: (25000,)
# 137
#   eeg: (25000,)
#   emg: (25000,)
# 138
#   eeg: (25000,)
#   emg: (25000,)
# 139
#   eeg: (25000,)
#   emg: (25000,)
# 14
#   eeg: (25000,)
#   emg: (25000,)
# 140
#   eeg: (25000,)
#   emg: (25000,)
# 141
#   eeg: (25000,)
#   emg: (25000,)
# 142
#   eeg: (25000,)
#   emg: (25000,)
# 143
#   eeg: (25000,)
#   emg: (25000,)
# 144
#   eeg: (25000,)
#   emg: (25000,)
# 145
#   eeg: (25000,)
#   emg: (25000,)
# 146
#   eeg: (25000,)
#   emg: (25000,)
# 147
#   eeg: (25000,)
#   emg: (25000,)
# 148
#   eeg: (25000,)
#   emg: (25000,)
# 149
#   eeg: (25000,)
#   emg: (25000,)
# 15
#   eeg: (25000,)
#   emg: (25000,)
# 150
#   eeg: (25000,)
#   emg: (25000,)
# 151
#   eeg: (25000,)
#   emg: (25000,)
# 152
#   eeg: (25000,)
#   emg: (25000,)
# 153
#   eeg: (25000,)
#   emg: (25000,)
# 154
#   eeg: (25000,)
#   emg: (25000,)
# 155
#   eeg: (25000,)
#   emg: (25000,)
# 156
#   eeg: (25000,)
#   emg: (25000,)
# 157
#   eeg: (25000,)
#   emg: (25000,)
# 158
#   eeg: (25000,)
#   emg: (25000,)
# 159
#   eeg: (25000,)
#   emg: (25000,)
# 16
#   eeg: (25000,)
#   emg: (25000,)
# 160
#   eeg: (25000,)
#   emg: (25000,)
# 161
#   eeg: (25000,)
#   emg: (25000,)
# 162
#   eeg: (25000,)
#   emg: (25000,)
# 163
#   eeg: (25000,)
#   emg: (25000,)
# 164
#   eeg: (25000,)
#   emg: (25000,)
# 165
#   eeg: (25000,)
#   emg: (25000,)
# 166
#   eeg: (25000,)
#   emg: (25000,)
# 167
#   eeg: (25000,)
#   emg: (25000,)
# 168
#   eeg: (25000,)
#   emg: (25000,)
# 169
#   eeg: (25000,)
#   emg: (25000,)
# 17
#   eeg: (25000,)
#   emg: (25000,)
# 170
#   eeg: (25000,)
#   emg: (25000,)
# 171
#   eeg: (25000,)
#   emg: (25000,)
# 172
#   eeg: (25000,)
#   emg: (25000,)
# 173
#   eeg: (25000,)
#   emg: (25000,)
# 174
#   eeg: (25000,)
#   emg: (25000,)
# 175
#   eeg: (25000,)
#   emg: (25000,)
# 176
#   eeg: (25000,)
#   emg: (25000,)
# 177
#   eeg: (25000,)
#   emg: (25000,)
# 178
#   eeg: (25000,)
#   emg: (25000,)
# 179
#   eeg: (25000,)
#   emg: (25000,)
# 18
#   eeg: (25000,)
#   emg: (25000,)
# 180
#   eeg: (25000,)
#   emg: (25000,)
# 181
#   eeg: (25000,)
#   emg: (25000,)
# 182
#   eeg: (25000,)
#   emg: (25000,)
# 183
#   eeg: (25000,)
#   emg: (25000,)
# 184
#   eeg: (25000,)
#   emg: (25000,)
# 185
#   eeg: (25000,)
#   emg: (25000,)
# 186
#   eeg: (25000,)
#   emg: (25000,)
# 187
#   eeg: (25000,)
#   emg: (25000,)
# 188
#   eeg: (25000,)
#   emg: (25000,)
# 189
#   eeg: (25000,)
#   emg: (25000,)
# 19
#   eeg: (25000,)
#   emg: (25000,)
# 190
#   eeg: (25000,)
#   emg: (25000,)
# 191
#   eeg: (25000,)
#   emg: (25000,)
# 192
#   eeg: (25000,)
#   emg: (25000,)
# 193
#   eeg: (25000,)
#   emg: (25000,)
# 194
#   eeg: (25000,)
#   emg: (25000,)
# 195
#   eeg: (25000,)
#   emg: (25000,)
# 196
#   eeg: (25000,)
#   emg: (25000,)
# 197
#   eeg: (25000,)
#   emg: (25000,)
# 198
#   eeg: (25000,)
#   emg: (25000,)
# 199
#   eeg: (25000,)
#   emg: (25000,)
# 2
#   eeg: (25000,)
#   emg: (25000,)
# 20
#   eeg: (25000,)
#   emg: (25000,)
# 200
#   eeg: (25000,)
#   emg: (25000,)
# 201
#   eeg: (25000,)
#   emg: (25000,)
# 202
#   eeg: (25000,)
#   emg: (25000,)
# 203
#   eeg: (25000,)
#   emg: (25000,)
# 204
#   eeg: (25000,)
#   emg: (25000,)
# 205
#   eeg: (25000,)
#   emg: (25000,)
# 206
#   eeg: (25000,)
#   emg: (25000,)
# 207
#   eeg: (25000,)
#   emg: (25000,)
# 208
#   eeg: (25000,)
#   emg: (25000,)
# 209
#   eeg: (25000,)
#   emg: (25000,)
# 21
#   eeg: (25000,)
#   emg: (25000,)
# 210
#   eeg: (25000,)
#   emg: (25000,)
# 211
#   eeg: (25000,)
#   emg: (25000,)
# 212
#   eeg: (25000,)
#   emg: (25000,)
# 213
#   eeg: (25000,)
#   emg: (25000,)
# 214
#   eeg: (25000,)
#   emg: (25000,)
# 215
#   eeg: (25000,)
#   emg: (25000,)
# 216
#   eeg: (25000,)
#   emg: (25000,)
# 217
#   eeg: (25000,)
#   emg: (25000,)
# 218
#   eeg: (25000,)
#   emg: (25000,)
# 219
#   eeg: (25000,)
#   emg: (25000,)
# 22
#   eeg: (25000,)
#   emg: (25000,)
# 220
#   eeg: (25000,)
#   emg: (25000,)
# 221
#   eeg: (25000,)
#   emg: (25000,)
# 222
#   eeg: (25000,)
#   emg: (25000,)
# 223
#   eeg: (25000,)
#   emg: (25000,)
# 224
#   eeg: (25000,)
#   emg: (25000,)
# 225
#   eeg: (25000,)
#   emg: (25000,)
# 226
#   eeg: (25000,)
#   emg: (25000,)
# 227
#   eeg: (25000,)
#   emg: (25000,)
# 228
#   eeg: (25000,)
#   emg: (25000,)
# 229
#   eeg: (25000,)
#   emg: (25000,)
# 23
#   eeg: (25000,)
#   emg: (25000,)
# 230
#   eeg: (25000,)
#   emg: (25000,)
# 231
#   eeg: (25000,)
#   emg: (25000,)
# 232
#   eeg: (25000,)
#   emg: (25000,)
# 233
#   eeg: (25000,)
#   emg: (25000,)
# 234
#   eeg: (25000,)
#   emg: (25000,)
# 235
#   eeg: (25000,)
#   emg: (25000,)
# 236
#   eeg: (25000,)
#   emg: (25000,)
# 237
#   eeg: (25000,)
#   emg: (25000,)
# 238
#   eeg: (25000,)
#   emg: (25000,)
# 239
#   eeg: (25000,)
#   emg: (25000,)
# 24
#   eeg: (25000,)
#   emg: (25000,)
# 240
#   eeg: (25000,)
#   emg: (25000,)
# 241
#   eeg: (25000,)
#   emg: (25000,)
# 242
#   eeg: (25000,)
#   emg: (25000,)
# 243
#   eeg: (25000,)
#   emg: (25000,)
# 244
#   eeg: (25000,)
#   emg: (25000,)
# 245
#   eeg: (25000,)
#   emg: (25000,)
# 246
#   eeg: (25000,)
#   emg: (25000,)
# 247
#   eeg: (25000,)
#   emg: (25000,)
# 248
#   eeg: (25000,)
#   emg: (25000,)
# 249
#   eeg: (25000,)
#   emg: (25000,)
# 25
#   eeg: (25000,)
#   emg: (25000,)
# 250
#   eeg: (25000,)
#   emg: (25000,)
# 251
#   eeg: (25000,)
#   emg: (25000,)
# 252
#   eeg: (25000,)
#   emg: (25000,)
# 253
#   eeg: (25000,)
#   emg: (25000,)
# 254
#   eeg: (25000,)
#   emg: (25000,)
# 255
#   eeg: (25000,)
#   emg: (25000,)
# 256
#   eeg: (25000,)
#   emg: (25000,)
# 257
#   eeg: (25000,)
#   emg: (25000,)
# 258
#   eeg: (25000,)
#   emg: (25000,)
# 259
#   eeg: (25000,)
#   emg: (25000,)
# 26
#   eeg: (25000,)
#   emg: (25000,)
# 260
#   eeg: (25000,)
#   emg: (25000,)
# 261
#   eeg: (25000,)
#   emg: (25000,)
# 262
#   eeg: (25000,)
#   emg: (25000,)
# 263
#   eeg: (25000,)
#   emg: (25000,)
# 264
#   eeg: (25000,)
#   emg: (25000,)
# 265
#   eeg: (25000,)
#   emg: (25000,)
# 266
#   eeg: (25000,)
#   emg: (25000,)
# 267
#   eeg: (25000,)
#   emg: (25000,)
# 268
#   eeg: (25000,)
#   emg: (25000,)
# 269
#   eeg: (25000,)
#   emg: (25000,)
# 27
#   eeg: (25000,)
#   emg: (25000,)
# 270
#   eeg: (25000,)
#   emg: (25000,)
# 271
#   eeg: (25000,)
#   emg: (25000,)
# 272
#   eeg: (25000,)
#   emg: (25000,)
# 273
#   eeg: (25000,)
#   emg: (25000,)
# 274
#   eeg: (25000,)
#   emg: (25000,)
# 275
#   eeg: (25000,)
#   emg: (25000,)
# 276
#   eeg: (25000,)
#   emg: (25000,)
# 277
#   eeg: (25000,)
#   emg: (25000,)
# 278
#   eeg: (25000,)
#   emg: (25000,)
# 279
#   eeg: (25000,)
#   emg: (25000,)
# 28
#   eeg: (25000,)
#   emg: (25000,)
# 280
#   eeg: (25000,)
#   emg: (25000,)
# 281
#   eeg: (25000,)
#   emg: (25000,)
# 282
#   eeg: (25000,)
#   emg: (25000,)
# 283
#   eeg: (25000,)
#   emg: (25000,)
# 284
#   eeg: (25000,)
#   emg: (25000,)
# 285
#   eeg: (25000,)
#   emg: (25000,)
# 286
#   eeg: (25000,)
#   emg: (25000,)
# 287
#   eeg: (25000,)
#   emg: (25000,)
# 288
#   eeg: (25000,)
#   emg: (25000,)
# 289
#   eeg: (25000,)
#   emg: (25000,)
# 29
#   eeg: (25000,)
#   emg: (25000,)
# 290
#   eeg: (25000,)
#   emg: (25000,)
# 291
#   eeg: (25000,)
#   emg: (25000,)
# 292
#   eeg: (25000,)
#   emg: (25000,)
# 293
#   eeg: (25000,)
#   emg: (25000,)
# 294
#   eeg: (25000,)
#   emg: (25000,)
# 295
#   eeg: (25000,)
#   emg: (25000,)
# 296
#   eeg: (25000,)
#   emg: (25000,)
# 297
#   eeg: (25000,)
#   emg: (25000,)
# 298
#   eeg: (25000,)
#   emg: (25000,)
# 299
#   eeg: (25000,)
#   emg: (25000,)
# 3
#   eeg: (25000,)
#   emg: (25000,)
# 30
#   eeg: (25000,)
#   emg: (25000,)
# 300
#   eeg: (25000,)
#   emg: (25000,)
# 301
#   eeg: (25000,)
#   emg: (25000,)
# 302
#   eeg: (25000,)
#   emg: (25000,)
# 303
#   eeg: (25000,)
#   emg: (25000,)
# 304
#   eeg: (25000,)
#   emg: (25000,)
# 305
#   eeg: (25000,)
#   emg: (25000,)
# 306
#   eeg: (25000,)
#   emg: (25000,)
# 307
#   eeg: (25000,)
#   emg: (25000,)
# 308
#   eeg: (25000,)
#   emg: (25000,)
# 309
#   eeg: (25000,)
#   emg: (25000,)
# 31
#   eeg: (25000,)
#   emg: (25000,)
# 310
#   eeg: (25000,)
#   emg: (25000,)
# 311
#   eeg: (25000,)
#   emg: (25000,)
# 312
#   eeg: (25000,)
#   emg: (25000,)
# 313
#   eeg: (25000,)
#   emg: (25000,)
# 314
#   eeg: (25000,)
#   emg: (25000,)
# 315
#   eeg: (25000,)
#   emg: (25000,)
# 316
#   eeg: (25000,)
#   emg: (25000,)
# 317
#   eeg: (25000,)
#   emg: (25000,)
# 318
#   eeg: (25000,)
#   emg: (25000,)
# 319
#   eeg: (25000,)
#   emg: (25000,)
# 32
#   eeg: (25000,)
#   emg: (25000,)
# 320
#   eeg: (25000,)
#   emg: (25000,)
# 321
#   eeg: (25000,)
#   emg: (25000,)
# 322
#   eeg: (25000,)
#   emg: (25000,)
# 323
#   eeg: (25000,)
#   emg: (25000,)
# 324
#   eeg: (25000,)
#   emg: (25000,)
# 325
#   eeg: (25000,)
#   emg: (25000,)
# 326
#   eeg: (25000,)
#   emg: (25000,)
# 327
#   eeg: (25000,)
#   emg: (25000,)
# 328
#   eeg: (25000,)
#   emg: (25000,)
# 329
#   eeg: (25000,)
#   emg: (25000,)
# 33
#   eeg: (25000,)
#   emg: (25000,)
# 330
#   eeg: (25000,)
#   emg: (25000,)
# 331
#   eeg: (25000,)
#   emg: (25000,)
# 332
#   eeg: (25000,)
#   emg: (25000,)
# 333
#   eeg: (25000,)
#   emg: (25000,)
# 334
#   eeg: (25000,)
#   emg: (25000,)
# 335
#   eeg: (25000,)
#   emg: (25000,)
# 336
#   eeg: (25000,)
#   emg: (25000,)
# 337
#   eeg: (25000,)
#   emg: (25000,)
# 338
#   eeg: (25000,)
#   emg: (25000,)
# 339
#   eeg: (25000,)
#   emg: (25000,)
# 34
#   eeg: (25000,)
#   emg: (25000,)
# 340
#   eeg: (25000,)
#   emg: (25000,)
# 341
#   eeg: (25000,)
#   emg: (25000,)
# 342
#   eeg: (25000,)
#   emg: (25000,)
# 343
#   eeg: (25000,)
#   emg: (25000,)
# 344
#   eeg: (25000,)
#   emg: (25000,)
# 345
#   eeg: (25000,)
#   emg: (25000,)
# 346
#   eeg: (25000,)
#   emg: (25000,)
# 347
#   eeg: (25000,)
#   emg: (25000,)
# 348
#   eeg: (25000,)
#   emg: (25000,)
# 349
#   eeg: (25000,)
#   emg: (25000,)
# 35
#   eeg: (25000,)
#   emg: (25000,)
# 350
#   eeg: (25000,)
#   emg: (25000,)
# 351
#   eeg: (25000,)
#   emg: (25000,)
# 352
#   eeg: (25000,)
#   emg: (25000,)
# 353
#   eeg: (25000,)
#   emg: (25000,)
# 354
#   eeg: (25000,)
#   emg: (25000,)
# 355
#   eeg: (25000,)
#   emg: (25000,)
# 356
#   eeg: (25000,)
#   emg: (25000,)
# 357
#   eeg: (25000,)
#   emg: (25000,)
# 358
#   eeg: (25000,)
#   emg: (25000,)
# 359
#   eeg: (25000,)
#   emg: (25000,)
# 36
#   eeg: (25000,)
#   emg: (25000,)
# 360
#   eeg: (25000,)
#   emg: (25000,)
# 361
#   eeg: (25000,)
#   emg: (25000,)
# 362
#   eeg: (25000,)
#   emg: (25000,)
# 363
#   eeg: (25000,)
#   emg: (25000,)
# 364
#   eeg: (25000,)
#   emg: (25000,)
# 365
#   eeg: (25000,)
#   emg: (25000,)
# 366
#   eeg: (25000,)
#   emg: (25000,)
# 367
#   eeg: (25000,)
#   emg: (25000,)
# 368
#   eeg: (25000,)
#   emg: (25000,)
# 369
#   eeg: (25000,)
#   emg: (25000,)
# 37
#   eeg: (25000,)
#   emg: (25000,)
# 370
#   eeg: (25000,)
#   emg: (25000,)
# 371
#   eeg: (25000,)
#   emg: (25000,)
# 372
#   eeg: (25000,)
#   emg: (25000,)
# 373
#   eeg: (25000,)
#   emg: (25000,)
# 374
#   eeg: (25000,)
#   emg: (25000,)
# 375
#   eeg: (25000,)
#   emg: (25000,)
# 376
#   eeg: (25000,)
#   emg: (25000,)
# 377
#   eeg: (25000,)
#   emg: (25000,)
# 378
#   eeg: (25000,)
#   emg: (25000,)
# 379
#   eeg: (25000,)
#   emg: (25000,)
# 38
#   eeg: (25000,)
#   emg: (25000,)
# 380
#   eeg: (25000,)
#   emg: (25000,)
# 381
#   eeg: (25000,)
#   emg: (25000,)
# 382
#   eeg: (25000,)
#   emg: (25000,)
# 383
#   eeg: (25000,)
#   emg: (25000,)
# 384
#   eeg: (25000,)
#   emg: (25000,)
# 385
#   eeg: (25000,)
#   emg: (25000,)
# 386
#   eeg: (25000,)
#   emg: (25000,)
# 387
#   eeg: (25000,)
#   emg: (25000,)
# 388
#   eeg: (25000,)
#   emg: (25000,)
# 389
#   eeg: (25000,)
#   emg: (25000,)
# 39
#   eeg: (25000,)
#   emg: (25000,)
# 390
#   eeg: (25000,)
#   emg: (25000,)
# 391
#   eeg: (25000,)
#   emg: (25000,)
# 392
#   eeg: (25000,)
#   emg: (25000,)
# 393
#   eeg: (25000,)
#   emg: (25000,)
# 394
#   eeg: (25000,)
#   emg: (25000,)
# 395
#   eeg: (25000,)
#   emg: (25000,)
# 396
#   eeg: (25000,)
#   emg: (25000,)
# 397
#   eeg: (25000,)
#   emg: (25000,)
# 398
#   eeg: (25000,)
#   emg: (25000,)
# 399
#   eeg: (25000,)
#   emg: (25000,)
# 4
#   eeg: (25000,)
#   emg: (25000,)
# 40
#   eeg: (25000,)
#   emg: (25000,)
# 400
#   eeg: (25000,)
#   emg: (25000,)
# 401
#   eeg: (25000,)
#   emg: (25000,)
# 402
#   eeg: (25000,)
#   emg: (25000,)
# 403
#   eeg: (25000,)
#   emg: (25000,)
# 404
#   eeg: (25000,)
#   emg: (25000,)
# 405
#   eeg: (25000,)
#   emg: (25000,)
# 406
#   eeg: (25000,)
#   emg: (25000,)
# 407
#   eeg: (25000,)
#   emg: (25000,)
# 408
#   eeg: (25000,)
#   emg: (25000,)
# 409
#   eeg: (25000,)
#   emg: (25000,)
# 41
#   eeg: (25000,)
#   emg: (25000,)
# 410
#   eeg: (25000,)
#   emg: (25000,)
# 411
#   eeg: (25000,)
#   emg: (25000,)
# 412
#   eeg: (25000,)
#   emg: (25000,)
# 413
#   eeg: (25000,)
#   emg: (25000,)
# 414
#   eeg: (25000,)
#   emg: (25000,)
# 415
#   eeg: (25000,)
#   emg: (25000,)
# 416
#   eeg: (25000,)
#   emg: (25000,)
# 417
#   eeg: (25000,)
#   emg: (25000,)
# 418
#   eeg: (25000,)
#   emg: (25000,)
# 419
#   eeg: (25000,)
#   emg: (25000,)
# 42
#   eeg: (25000,)
#   emg: (25000,)
# 420
#   eeg: (25000,)
#   emg: (25000,)
# 421
#   eeg: (25000,)
#   emg: (25000,)
# 422
#   eeg: (25000,)
#   emg: (25000,)
# 423
#   eeg: (25000,)
#   emg: (25000,)
# 424
#   eeg: (25000,)
#   emg: (25000,)
# 425
#   eeg: (25000,)
#   emg: (25000,)
# 426
#   eeg: (25000,)
#   emg: (25000,)
# 427
#   eeg: (25000,)
#   emg: (25000,)
# 428
#   eeg: (25000,)
#   emg: (25000,)
# 429
#   eeg: (25000,)
#   emg: (25000,)
# 43
#   eeg: (25000,)
#   emg: (25000,)
# 430
#   eeg: (25000,)
#   emg: (25000,)
# 431
#   eeg: (25000,)
#   emg: (25000,)
# 432
#   eeg: (25000,)
#   emg: (25000,)
# 433
#   eeg: (25000,)
#   emg: (25000,)
# 434
#   eeg: (25000,)
#   emg: (25000,)
# 435
#   eeg: (25000,)
#   emg: (25000,)
# 436
#   eeg: (25000,)
#   emg: (25000,)
# 437
#   eeg: (25000,)
#   emg: (25000,)
# 438
#   eeg: (25000,)
#   emg: (25000,)
# 439
#   eeg: (25000,)
#   emg: (25000,)
# 44
#   eeg: (25000,)
#   emg: (25000,)
# 440
#   eeg: (25000,)
#   emg: (25000,)
# 441
#   eeg: (25000,)
#   emg: (25000,)
# 442
#   eeg: (25000,)
#   emg: (25000,)
# 443
#   eeg: (25000,)
#   emg: (25000,)
# 444
#   eeg: (25000,)
#   emg: (25000,)
# 445
#   eeg: (25000,)
#   emg: (25000,)
# 446
#   eeg: (25000,)
#   emg: (25000,)
# 447
#   eeg: (25000,)
#   emg: (25000,)
# 448
#   eeg: (25000,)
#   emg: (25000,)
# 449
#   eeg: (25000,)
#   emg: (25000,)
# 45
#   eeg: (25000,)
#   emg: (25000,)
# 450
#   eeg: (25000,)
#   emg: (25000,)
# 451
#   eeg: (25000,)
#   emg: (25000,)
# 452
#   eeg: (25000,)
#   emg: (25000,)
# 453
#   eeg: (25000,)
#   emg: (25000,)
# 454
#   eeg: (25000,)
#   emg: (25000,)
# 455
#   eeg: (25000,)
#   emg: (25000,)
# 456
#   eeg: (25000,)
#   emg: (25000,)
# 457
#   eeg: (25000,)
#   emg: (25000,)
# 458
#   eeg: (25000,)
#   emg: (25000,)
# 459
#   eeg: (25000,)
#   emg: (25000,)
# 46
#   eeg: (25000,)
#   emg: (25000,)
# 460
#   eeg: (25000,)
#   emg: (25000,)
# 461
#   eeg: (25000,)
#   emg: (25000,)
# 462
#   eeg: (25000,)
#   emg: (25000,)
# 463
#   eeg: (25000,)
#   emg: (25000,)
# 464
#   eeg: (25000,)
#   emg: (25000,)
# 465
#   eeg: (25000,)
#   emg: (25000,)
# 466
#   eeg: (25000,)
#   emg: (25000,)
# 467
#   eeg: (25000,)
#   emg: (25000,)
# 468
#   eeg: (25000,)
#   emg: (25000,)
# 469
#   eeg: (25000,)
#   emg: (25000,)
# 47
#   eeg: (25000,)
#   emg: (25000,)
# 470
#   eeg: (25000,)
#   emg: (25000,)
# 471
#   eeg: (25000,)
#   emg: (25000,)
# 472
#   eeg: (25000,)
#   emg: (25000,)
# 473
#   eeg: (25000,)
#   emg: (25000,)
# 474
#   eeg: (25000,)
#   emg: (25000,)
# 475
#   eeg: (25000,)
#   emg: (25000,)
# 476
#   eeg: (25000,)
#   emg: (25000,)
# 477
#   eeg: (25000,)
#   emg: (25000,)
# 478
#   eeg: (25000,)
#   emg: (25000,)
# 479
#   eeg: (25000,)
#   emg: (25000,)
# 48
#   eeg: (25000,)
#   emg: (25000,)
# 480
#   eeg: (25000,)
#   emg: (25000,)
# 481
#   eeg: (25000,)
#   emg: (25000,)
# 482
#   eeg: (25000,)
#   emg: (25000,)
# 483
#   eeg: (25000,)
#   emg: (25000,)
# 484
#   eeg: (25000,)
#   emg: (25000,)
# 485
#   eeg: (25000,)
#   emg: (25000,)
# 486
#   eeg: (25000,)
#   emg: (25000,)
# 487
#   eeg: (25000,)
#   emg: (25000,)
# 488
#   eeg: (25000,)
#   emg: (25000,)
# 489
#   eeg: (25000,)
#   emg: (25000,)
# 49
#   eeg: (25000,)
#   emg: (25000,)
# 490
#   eeg: (25000,)
#   emg: (25000,)
# 491
#   eeg: (25000,)
#   emg: (25000,)
# 492
#   eeg: (25000,)
#   emg: (25000,)
# 493
#   eeg: (25000,)
#   emg: (25000,)
# 494
#   eeg: (25000,)
#   emg: (25000,)
# 495
#   eeg: (25000,)
#   emg: (25000,)
# 496
#   eeg: (25000,)
#   emg: (25000,)
# 497
#   eeg: (25000,)
#   emg: (25000,)
# 498
#   eeg: (25000,)
#   emg: (25000,)
# 499
#   eeg: (25000,)
#   emg: (25000,)
# 5
#   eeg: (25000,)
#   emg: (25000,)
# 50
#   eeg: (25000,)
#   emg: (25000,)
# 500
#   eeg: (25000,)
#   emg: (25000,)
# 501
#   eeg: (25000,)
#   emg: (25000,)
# 502
#   eeg: (25000,)
#   emg: (25000,)
# 503
#   eeg: (25000,)
#   emg: (25000,)
# 504
#   eeg: (25000,)
#   emg: (25000,)
# 505
#   eeg: (25000,)
#   emg: (25000,)
# 506
#   eeg: (25000,)
#   emg: (25000,)
# 507
#   eeg: (25000,)
#   emg: (25000,)
# 508
#   eeg: (25000,)
#   emg: (25000,)
# 509
#   eeg: (25000,)
#   emg: (25000,)
# 51
#   eeg: (25000,)
#   emg: (25000,)
# 510
#   eeg: (25000,)
#   emg: (25000,)
# 511
#   eeg: (25000,)
#   emg: (25000,)
# 512
#   eeg: (25000,)
#   emg: (25000,)
# 513
#   eeg: (25000,)
#   emg: (25000,)
# 514
#   eeg: (25000,)
#   emg: (25000,)
# 515
#   eeg: (25000,)
#   emg: (25000,)
# 516
#   eeg: (25000,)
#   emg: (25000,)
# 517
#   eeg: (25000,)
#   emg: (25000,)
# 518
#   eeg: (25000,)
#   emg: (25000,)
# 519
#   eeg: (25000,)
#   emg: (25000,)
# 52
#   eeg: (25000,)
#   emg: (25000,)
# 520
#   eeg: (25000,)
#   emg: (25000,)
# 521
#   eeg: (25000,)
#   emg: (25000,)
# 522
#   eeg: (25000,)
#   emg: (25000,)
# 523
#   eeg: (25000,)
#   emg: (25000,)
# 524
#   eeg: (25000,)
#   emg: (25000,)
# 525
#   eeg: (25000,)
#   emg: (25000,)
# 526
#   eeg: (25000,)
#   emg: (25000,)
# 527
#   eeg: (25000,)
#   emg: (25000,)
# 528
#   eeg: (25000,)
#   emg: (25000,)
# 529
#   eeg: (25000,)
#   emg: (25000,)
# 53
#   eeg: (25000,)
#   emg: (25000,)
# 530
#   eeg: (25000,)
#   emg: (25000,)
# 531
#   eeg: (25000,)
#   emg: (25000,)
# 532
#   eeg: (25000,)
#   emg: (25000,)
# 533
#   eeg: (25000,)
#   emg: (25000,)
# 534
#   eeg: (25000,)
#   emg: (25000,)
# 535
#   eeg: (25000,)
#   emg: (25000,)
# 536
#   eeg: (25000,)
#   emg: (25000,)
# 537
#   eeg: (25000,)
#   emg: (25000,)
# 538
#   eeg: (25000,)
#   emg: (25000,)
# 539
#   eeg: (25000,)
#   emg: (25000,)
# 54
#   eeg: (25000,)
#   emg: (25000,)
# 540
#   eeg: (25000,)
#   emg: (25000,)
# 541
#   eeg: (25000,)
#   emg: (25000,)
# 542
#   eeg: (25000,)
#   emg: (25000,)
# 543
#   eeg: (25000,)
#   emg: (25000,)
# 544
#   eeg: (25000,)
#   emg: (25000,)
# 545
#   eeg: (25000,)
#   emg: (25000,)
# 546
#   eeg: (25000,)
#   emg: (25000,)
# 547
#   eeg: (25000,)
#   emg: (25000,)
# 548
#   eeg: (25000,)
#   emg: (25000,)
# 549
#   eeg: (25000,)
#   emg: (25000,)
# 55
#   eeg: (25000,)
#   emg: (25000,)
# 550
#   eeg: (25000,)
#   emg: (25000,)
# 551
#   eeg: (25000,)
#   emg: (25000,)
# 552
#   eeg: (25000,)
#   emg: (25000,)
# 553
#   eeg: (25000,)
#   emg: (25000,)
# 554
#   eeg: (25000,)
#   emg: (25000,)
# 555
#   eeg: (25000,)
#   emg: (25000,)
# 556
#   eeg: (25000,)
#   emg: (25000,)
# 557
#   eeg: (25000,)
#   emg: (25000,)
# 558
#   eeg: (25000,)
#   emg: (25000,)
# 559
#   eeg: (25000,)
#   emg: (25000,)
# 56
#   eeg: (25000,)
#   emg: (25000,)
# 560
#   eeg: (25000,)
#   emg: (25000,)
# 561
#   eeg: (25000,)
#   emg: (25000,)
# 562
#   eeg: (25000,)
#   emg: (25000,)
# 563
#   eeg: (25000,)
#   emg: (25000,)
# 564
#   eeg: (25000,)
#   emg: (25000,)
# 565
#   eeg: (25000,)
#   emg: (25000,)
# 566
#   eeg: (25000,)
#   emg: (25000,)
# 567
#   eeg: (25000,)
#   emg: (25000,)
# 568
#   eeg: (25000,)
#   emg: (25000,)
# 569
#   eeg: (25000,)
#   emg: (25000,)
# 57
#   eeg: (25000,)
#   emg: (25000,)
# 570
#   eeg: (25000,)
#   emg: (25000,)
# 571
#   eeg: (25000,)
#   emg: (25000,)
# 572
#   eeg: (25000,)
#   emg: (25000,)
# 573
#   eeg: (25000,)
#   emg: (25000,)
# 574
#   eeg: (25000,)
#   emg: (25000,)
# 575
#   eeg: (25000,)
#   emg: (25000,)
# 576
#   eeg: (25000,)
#   emg: (25000,)
# 577
#   eeg: (25000,)
#   emg: (25000,)
# 578
#   eeg: (25000,)
#   emg: (25000,)
# 579
#   eeg: (25000,)
#   emg: (25000,)
# 58
#   eeg: (25000,)
#   emg: (25000,)
# 580
#   eeg: (25000,)
#   emg: (25000,)
# 581
#   eeg: (25000,)
#   emg: (25000,)
# 582
#   eeg: (25000,)
#   emg: (25000,)
# 583
#   eeg: (25000,)
#   emg: (25000,)
# 584
#   eeg: (25000,)
#   emg: (25000,)
# 585
#   eeg: (25000,)
#   emg: (25000,)
# 586
#   eeg: (25000,)
#   emg: (25000,)
# 587
#   eeg: (25000,)
#   emg: (25000,)
# 588
#   eeg: (25000,)
#   emg: (25000,)
# 589
#   eeg: (25000,)
#   emg: (25000,)
# 59
#   eeg: (25000,)
#   emg: (25000,)
# 590
#   eeg: (25000,)
#   emg: (25000,)
# 591
#   eeg: (25000,)
#   emg: (25000,)
# 592
#   eeg: (25000,)
#   emg: (25000,)
# 593
#   eeg: (25000,)
#   emg: (25000,)
# 594
#   eeg: (25000,)
#   emg: (25000,)
# 595
#   eeg: (25000,)
#   emg: (25000,)
# 596
#   eeg: (25000,)
#   emg: (25000,)
# 597
#   eeg: (25000,)
#   emg: (25000,)
# 598
#   eeg: (25000,)
#   emg: (25000,)
# 599
#   eeg: (25000,)
#   emg: (25000,)
# 6
#   eeg: (25000,)
#   emg: (25000,)
# 60
#   eeg: (25000,)
#   emg: (25000,)
# 600
#   eeg: (25000,)
#   emg: (25000,)
# 601
#   eeg: (25000,)
#   emg: (25000,)
# 602
#   eeg: (25000,)
#   emg: (25000,)
# 603
#   eeg: (25000,)
#   emg: (25000,)
# 604
#   eeg: (25000,)
#   emg: (25000,)
# 605
#   eeg: (25000,)
#   emg: (25000,)
# 606
#   eeg: (25000,)
#   emg: (25000,)
# 607
#   eeg: (25000,)
#   emg: (25000,)
# 608
#   eeg: (25000,)
#   emg: (25000,)
# 609
#   eeg: (25000,)
#   emg: (25000,)
# 61
#   eeg: (25000,)
#   emg: (25000,)
# 610
#   eeg: (25000,)
#   emg: (25000,)
# 611
#   eeg: (25000,)
#   emg: (25000,)
# 612
#   eeg: (25000,)
#   emg: (25000,)
# 613
#   eeg: (25000,)
#   emg: (25000,)
# 614
#   eeg: (25000,)
#   emg: (25000,)
# 615
#   eeg: (25000,)
#   emg: (25000,)
# 616
#   eeg: (25000,)
#   emg: (25000,)
# 617
#   eeg: (25000,)
#   emg: (25000,)
# 618
#   eeg: (25000,)
#   emg: (25000,)
# 619
#   eeg: (25000,)
#   emg: (25000,)
# 62
#   eeg: (25000,)
#   emg: (25000,)
# 620
#   eeg: (25000,)
#   emg: (25000,)
# 621
#   eeg: (25000,)
#   emg: (25000,)
# 622
#   eeg: (25000,)
#   emg: (25000,)
# 623
#   eeg: (25000,)
#   emg: (25000,)
# 624
#   eeg: (25000,)
#   emg: (25000,)
# 625
#   eeg: (25000,)
#   emg: (25000,)
# 626
#   eeg: (25000,)
#   emg: (25000,)
# 627
#   eeg: (25000,)
#   emg: (25000,)
# 628
#   eeg: (25000,)
#   emg: (25000,)
# 629
#   eeg: (25000,)
#   emg: (25000,)
# 63
#   eeg: (25000,)
#   emg: (25000,)
# 630
#   eeg: (25000,)
#   emg: (25000,)
# 631
#   eeg: (25000,)
#   emg: (25000,)
# 632
#   eeg: (25000,)
#   emg: (25000,)
# 633
#   eeg: (25000,)
#   emg: (25000,)
# 634
#   eeg: (25000,)
#   emg: (25000,)
# 635
#   eeg: (25000,)
#   emg: (25000,)
# 636
#   eeg: (25000,)
#   emg: (25000,)
# 637
#   eeg: (25000,)
#   emg: (25000,)
# 638
#   eeg: (25000,)
#   emg: (25000,)
# 639
#   eeg: (25000,)
#   emg: (25000,)
# 64
#   eeg: (25000,)
#   emg: (25000,)
# 640
#   eeg: (25000,)
#   emg: (25000,)
# 641
#   eeg: (25000,)
#   emg: (25000,)
# 642
#   eeg: (25000,)
#   emg: (25000,)
# 643
#   eeg: (25000,)
#   emg: (25000,)
# 644
#   eeg: (25000,)
#   emg: (25000,)
# 645
#   eeg: (25000,)
#   emg: (25000,)
# 646
#   eeg: (25000,)
#   emg: (25000,)
# 647
#   eeg: (25000,)
#   emg: (25000,)
# 648
#   eeg: (25000,)
#   emg: (25000,)
# 649
#   eeg: (25000,)
#   emg: (25000,)
# 65
#   eeg: (25000,)
#   emg: (25000,)
# 650
#   eeg: (25000,)
#   emg: (25000,)
# 651
#   eeg: (25000,)
#   emg: (25000,)
# 652
#   eeg: (25000,)
#   emg: (25000,)
# 653
#   eeg: (25000,)
#   emg: (25000,)
# 654
#   eeg: (25000,)
#   emg: (25000,)
# 655
#   eeg: (25000,)
#   emg: (25000,)
# 656
#   eeg: (25000,)
#   emg: (25000,)
# 657
#   eeg: (25000,)
#   emg: (25000,)
# 658
#   eeg: (25000,)
#   emg: (25000,)
# 659
#   eeg: (25000,)
#   emg: (25000,)
# 66
#   eeg: (25000,)
#   emg: (25000,)
# 660
#   eeg: (25000,)
#   emg: (25000,)
# 661
#   eeg: (25000,)
#   emg: (25000,)
# 662
#   eeg: (25000,)
#   emg: (25000,)
# 663
#   eeg: (25000,)
#   emg: (25000,)
# 664
#   eeg: (25000,)
#   emg: (25000,)
# 665
#   eeg: (25000,)
#   emg: (25000,)
# 666
#   eeg: (25000,)
#   emg: (25000,)
# 667
#   eeg: (25000,)
#   emg: (25000,)
# 668
#   eeg: (25000,)
#   emg: (25000,)
# 669
#   eeg: (25000,)
#   emg: (25000,)
# 67
#   eeg: (25000,)
#   emg: (25000,)
# 670
#   eeg: (25000,)
#   emg: (25000,)
# 671
#   eeg: (25000,)
#   emg: (25000,)
# 672
#   eeg: (25000,)
#   emg: (25000,)
# 673
#   eeg: (25000,)
#   emg: (25000,)
# 674
#   eeg: (25000,)
#   emg: (25000,)
# 675
#   eeg: (25000,)
#   emg: (25000,)
# 676
#   eeg: (25000,)
#   emg: (25000,)
# 677
#   eeg: (25000,)
#   emg: (25000,)
# 678
#   eeg: (25000,)
#   emg: (25000,)
# 679
#   eeg: (25000,)
#   emg: (25000,)
# 68
#   eeg: (25000,)
#   emg: (25000,)
# 680
#   eeg: (25000,)
#   emg: (25000,)
# 681
#   eeg: (25000,)
#   emg: (25000,)
# 682
#   eeg: (25000,)
#   emg: (25000,)
# 683
#   eeg: (25000,)
#   emg: (25000,)
# 684
#   eeg: (25000,)
#   emg: (25000,)
# 685
#   eeg: (25000,)
#   emg: (25000,)
# 686
#   eeg: (25000,)
#   emg: (25000,)
# 687
#   eeg: (25000,)
#   emg: (25000,)
# 688
#   eeg: (25000,)
#   emg: (25000,)
# 689
#   eeg: (25000,)
#   emg: (25000,)
# 69
#   eeg: (25000,)
#   emg: (25000,)
# 690
#   eeg: (25000,)
#   emg: (25000,)
# 691
#   eeg: (25000,)
#   emg: (25000,)
# 692
#   eeg: (25000,)
#   emg: (25000,)
# 693
#   eeg: (25000,)
#   emg: (25000,)
# 694
#   eeg: (25000,)
#   emg: (25000,)
# 695
#   eeg: (25000,)
#   emg: (25000,)
# 696
#   eeg: (25000,)
#   emg: (25000,)
# 697
#   eeg: (25000,)
#   emg: (25000,)
# 698
#   eeg: (25000,)
#   emg: (25000,)
# 699
#   eeg: (25000,)
#   emg: (25000,)
# 7
#   eeg: (25000,)
#   emg: (25000,)
# 70
#   eeg: (25000,)
#   emg: (25000,)
# 700
#   eeg: (25000,)
#   emg: (25000,)
# 701
#   eeg: (25000,)
#   emg: (25000,)
# 702
#   eeg: (25000,)
#   emg: (25000,)
# 703
#   eeg: (25000,)
#   emg: (25000,)
# 704
#   eeg: (25000,)
#   emg: (25000,)
# 705
#   eeg: (25000,)
#   emg: (25000,)
# 706
#   eeg: (25000,)
#   emg: (25000,)
# 707
#   eeg: (25000,)
#   emg: (25000,)
# 708
#   eeg: (25000,)
#   emg: (25000,)
# 709
#   eeg: (25000,)
#   emg: (25000,)
# 71
#   eeg: (25000,)
#   emg: (25000,)
# 710
#   eeg: (25000,)
#   emg: (25000,)
# 711
#   eeg: (25000,)
#   emg: (25000,)
# 712
#   eeg: (25000,)
#   emg: (25000,)
# 713
#   eeg: (25000,)
#   emg: (25000,)
# 714
#   eeg: (25000,)
#   emg: (25000,)
# 715
#   eeg: (25000,)
#   emg: (25000,)
# 716
#   eeg: (25000,)
#   emg: (25000,)
# 717
#   eeg: (25000,)
#   emg: (25000,)
# 718
#   eeg: (25000,)
#   emg: (25000,)
# 719
#   eeg: (25000,)
#   emg: (25000,)
# 72
#   eeg: (25000,)
#   emg: (25000,)
# 720
#   eeg: (25000,)
#   emg: (25000,)
# 721
#   eeg: (25000,)
#   emg: (25000,)
# 722
#   eeg: (25000,)
#   emg: (25000,)
# 723
#   eeg: (25000,)
#   emg: (25000,)
# 724
#   eeg: (25000,)
#   emg: (25000,)
# 725
#   eeg: (25000,)
#   emg: (25000,)
# 726
#   eeg: (25000,)
#   emg: (25000,)
# 727
#   eeg: (25000,)
#   emg: (25000,)
# 728
#   eeg: (25000,)
#   emg: (25000,)
# 729
#   eeg: (25000,)
#   emg: (25000,)
# 73
#   eeg: (25000,)
#   emg: (25000,)
# 730
#   eeg: (25000,)
#   emg: (25000,)
# 731
#   eeg: (25000,)
#   emg: (25000,)
# 732
#   eeg: (25000,)
#   emg: (25000,)
# 733
#   eeg: (25000,)
#   emg: (25000,)
# 734
#   eeg: (25000,)
#   emg: (25000,)
# 735
#   eeg: (25000,)
#   emg: (25000,)
# 736
#   eeg: (25000,)
#   emg: (25000,)
# 737
#   eeg: (25000,)
#   emg: (25000,)
# 738
#   eeg: (25000,)
#   emg: (25000,)
# 739
#   eeg: (25000,)
#   emg: (25000,)
# 74
#   eeg: (25000,)
#   emg: (25000,)
# 740
#   eeg: (25000,)
#   emg: (25000,)
# 741
#   eeg: (25000,)
#   emg: (25000,)
# 742
#   eeg: (25000,)
#   emg: (25000,)
# 743
#   eeg: (25000,)
#   emg: (25000,)
# 744
#   eeg: (25000,)
#   emg: (25000,)
# 745
#   eeg: (25000,)
#   emg: (25000,)
# 746
#   eeg: (25000,)
#   emg: (25000,)
# 747
#   eeg: (25000,)
#   emg: (25000,)
# 748
#   eeg: (25000,)
#   emg: (25000,)
# 749
#   eeg: (25000,)
#   emg: (25000,)
# 75
#   eeg: (25000,)
#   emg: (25000,)
# 750
#   eeg: (25000,)
#   emg: (25000,)
# 751
#   eeg: (25000,)
#   emg: (25000,)
# 752
#   eeg: (25000,)
#   emg: (25000,)
# 753
#   eeg: (25000,)
#   emg: (25000,)
# 754
#   eeg: (25000,)
#   emg: (25000,)
# 755
#   eeg: (25000,)
#   emg: (25000,)
# 756
#   eeg: (25000,)
#   emg: (25000,)
# 757
#   eeg: (25000,)
#   emg: (25000,)
# 758
#   eeg: (25000,)
#   emg: (25000,)
# 759
#   eeg: (25000,)
#   emg: (25000,)
# 76
#   eeg: (25000,)
#   emg: (25000,)
# 760
#   eeg: (25000,)
#   emg: (25000,)
# 761
#   eeg: (25000,)
#   emg: (25000,)
# 762
#   eeg: (25000,)
#   emg: (25000,)
# 763
#   eeg: (25000,)
#   emg: (25000,)
# 764
#   eeg: (25000,)
#   emg: (25000,)
# 765
#   eeg: (25000,)
#   emg: (25000,)
# 766
#   eeg: (25000,)
#   emg: (25000,)
# 767
#   eeg: (25000,)
#   emg: (25000,)
# 768
#   eeg: (25000,)
#   emg: (25000,)
# 769
#   eeg: (25000,)
#   emg: (25000,)
# 77
#   eeg: (25000,)
#   emg: (25000,)
# 770
#   eeg: (25000,)
#   emg: (25000,)
# 771
#   eeg: (25000,)
#   emg: (25000,)
# 772
#   eeg: (25000,)
#   emg: (25000,)
# 773
#   eeg: (25000,)
#   emg: (25000,)
# 774
#   eeg: (25000,)
#   emg: (25000,)
# 775
#   eeg: (25000,)
#   emg: (25000,)
# 776
#   eeg: (25000,)
#   emg: (25000,)
# 777
#   eeg: (25000,)
#   emg: (25000,)
# 778
#   eeg: (25000,)
#   emg: (25000,)
# 779
#   eeg: (25000,)
#   emg: (25000,)
# 78
#   eeg: (25000,)
#   emg: (25000,)
# 780
#   eeg: (25000,)
#   emg: (25000,)
# 781
#   eeg: (25000,)
#   emg: (25000,)
# 782
#   eeg: (25000,)
#   emg: (25000,)
# 783
#   eeg: (25000,)
#   emg: (25000,)
# 784
#   eeg: (25000,)
#   emg: (25000,)
# 785
#   eeg: (25000,)
#   emg: (25000,)
# 786
#   eeg: (25000,)
#   emg: (25000,)
# 787
#   eeg: (25000,)
#   emg: (25000,)
# 788
#   eeg: (25000,)
#   emg: (25000,)
# 789
#   eeg: (25000,)
#   emg: (25000,)
# 79
#   eeg: (25000,)
#   emg: (25000,)
# 790
#   eeg: (25000,)
#   emg: (25000,)
# 791
#   eeg: (25000,)
#   emg: (25000,)
# 792
#   eeg: (25000,)
#   emg: (25000,)
# 793
#   eeg: (25000,)
#   emg: (25000,)
# 794
#   eeg: (25000,)
#   emg: (25000,)
# 795
#   eeg: (25000,)
#   emg: (25000,)
# 796
#   eeg: (25000,)
#   emg: (25000,)
# 797
#   eeg: (25000,)
#   emg: (25000,)
# 798
#   eeg: (25000,)
#   emg: (25000,)
# 799
#   eeg: (25000,)
#   emg: (25000,)
# 8
#   eeg: (25000,)
#   emg: (25000,)
# 80
#   eeg: (25000,)
#   emg: (25000,)
# 800
#   eeg: (25000,)
#   emg: (25000,)
# 801
#   eeg: (25000,)
#   emg: (25000,)
# 802
#   eeg: (25000,)
#   emg: (25000,)
# 803
#   eeg: (25000,)
#   emg: (25000,)
# 804
#   eeg: (25000,)
#   emg: (25000,)
# 805
#   eeg: (25000,)
#   emg: (25000,)
# 806
#   eeg: (25000,)
#   emg: (25000,)
# 807
#   eeg: (25000,)
#   emg: (25000,)
# 808
#   eeg: (25000,)
#   emg: (25000,)
# 809
#   eeg: (25000,)
#   emg: (25000,)
# 81
#   eeg: (25000,)
#   emg: (25000,)
# 810
#   eeg: (25000,)
#   emg: (25000,)
# 811
#   eeg: (25000,)
#   emg: (25000,)
# 812
#   eeg: (25000,)
#   emg: (25000,)
# 813
#   eeg: (25000,)
#   emg: (25000,)
# 814
#   eeg: (25000,)
#   emg: (25000,)
# 815
#   eeg: (25000,)
#   emg: (25000,)
# 816
#   eeg: (25000,)
#   emg: (25000,)
# 817
#   eeg: (25000,)
#   emg: (25000,)
# 818
#   eeg: (25000,)
#   emg: (25000,)
# 819
#   eeg: (25000,)
#   emg: (25000,)
# 82
#   eeg: (25000,)
#   emg: (25000,)
# 820
#   eeg: (25000,)
#   emg: (25000,)
# 821
#   eeg: (25000,)
#   emg: (25000,)
# 822
#   eeg: (25000,)
#   emg: (25000,)
# 823
#   eeg: (25000,)
#   emg: (25000,)
# 824
#   eeg: (25000,)
#   emg: (25000,)
# 825
#   eeg: (25000,)
#   emg: (25000,)
# 826
#   eeg: (25000,)
#   emg: (25000,)
# 827
#   eeg: (25000,)
#   emg: (25000,)
# 828
#   eeg: (25000,)
#   emg: (25000,)
# 829
#   eeg: (25000,)
#   emg: (25000,)
# 83
#   eeg: (25000,)
#   emg: (25000,)
# 830
#   eeg: (25000,)
#   emg: (25000,)
# 831
#   eeg: (25000,)
#   emg: (25000,)
# 832
#   eeg: (25000,)
#   emg: (25000,)
# 833
#   eeg: (25000,)
#   emg: (25000,)
# 834
#   eeg: (25000,)
#   emg: (25000,)
# 835
#   eeg: (25000,)
#   emg: (25000,)
# 836
#   eeg: (25000,)
#   emg: (25000,)
# 837
#   eeg: (25000,)
#   emg: (25000,)
# 838
#   eeg: (25000,)
#   emg: (25000,)
# 839
#   eeg: (25000,)
#   emg: (25000,)
# 84
#   eeg: (25000,)
#   emg: (25000,)
# 840
#   eeg: (25000,)
#   emg: (25000,)
# 841
#   eeg: (25000,)
#   emg: (25000,)
# 842
#   eeg: (25000,)
#   emg: (25000,)
# 843
#   eeg: (25000,)
#   emg: (25000,)
# 844
#   eeg: (25000,)
#   emg: (25000,)
# 845
#   eeg: (25000,)
#   emg: (25000,)
# 846
#   eeg: (25000,)
#   emg: (25000,)
# 847
#   eeg: (25000,)
#   emg: (25000,)
# 848
#   eeg: (25000,)
#   emg: (25000,)
# 849
#   eeg: (25000,)
#   emg: (25000,)
# 85
#   eeg: (25000,)
#   emg: (25000,)
# 850
#   eeg: (25000,)
#   emg: (25000,)
# 851
#   eeg: (25000,)
#   emg: (25000,)
# 852
#   eeg: (25000,)
#   emg: (25000,)
# 853
#   eeg: (25000,)
#   emg: (25000,)
# 854
#   eeg: (25000,)
#   emg: (25000,)
# 855
#   eeg: (25000,)
#   emg: (25000,)
# 856
#   eeg: (25000,)
#   emg: (25000,)
# 857
#   eeg: (25000,)
#   emg: (25000,)
# 858
#   eeg: (25000,)
#   emg: (25000,)
# 859
#   eeg: (25000,)
#   emg: (25000,)
# 86
#   eeg: (25000,)
#   emg: (25000,)
# 860
#   eeg: (25000,)
#   emg: (25000,)
# 861
#   eeg: (25000,)
#   emg: (25000,)
# 862
#   eeg: (25000,)
#   emg: (25000,)
# 863
#   eeg: (25000,)
#   emg: (25000,)
# 864
#   eeg: (25000,)
#   emg: (25000,)
# 865
#   eeg: (25000,)
#   emg: (25000,)
# 866
#   eeg: (25000,)
#   emg: (25000,)
# 867
#   eeg: (25000,)
#   emg: (25000,)
# 868
#   eeg: (25000,)
#   emg: (25000,)
# 869
#   eeg: (25000,)
#   emg: (25000,)
# 87
#   eeg: (25000,)
#   emg: (25000,)
# 870
#   eeg: (25000,)
#   emg: (25000,)
# 871
#   eeg: (25000,)
#   emg: (25000,)
# 872
#   eeg: (25000,)
#   emg: (25000,)
# 873
#   eeg: (25000,)
#   emg: (25000,)
# 874
#   eeg: (25000,)
#   emg: (25000,)
# 875
#   eeg: (25000,)
#   emg: (25000,)
# 876
#   eeg: (25000,)
#   emg: (25000,)
# 877
#   eeg: (25000,)
#   emg: (25000,)
# 878
#   eeg: (25000,)
#   emg: (25000,)
# 879
#   eeg: (25000,)
#   emg: (25000,)
# 88
#   eeg: (25000,)
#   emg: (25000,)
# 880
#   eeg: (25000,)
#   emg: (25000,)
# 881
#   eeg: (25000,)
#   emg: (25000,)
# 882
#   eeg: (25000,)
#   emg: (25000,)
# 883
#   eeg: (25000,)
#   emg: (25000,)
# 884
#   eeg: (25000,)
#   emg: (25000,)
# 885
#   eeg: (25000,)
#   emg: (25000,)
# 886
#   eeg: (25000,)
#   emg: (25000,)
# 887
#   eeg: (25000,)
#   emg: (25000,)
# 888
#   eeg: (25000,)
#   emg: (25000,)
# 889
#   eeg: (25000,)
#   emg: (25000,)
# 89
#   eeg: (25000,)
#   emg: (25000,)
# 890
#   eeg: (25000,)
#   emg: (25000,)
# 891
#   eeg: (25000,)
#   emg: (25000,)
# 892
#   eeg: (25000,)
#   emg: (25000,)
# 893
#   eeg: (25000,)
#   emg: (25000,)
# 894
#   eeg: (25000,)
#   emg: (25000,)
# 895
#   eeg: (25000,)
#   emg: (25000,)
# 896
#   eeg: (25000,)
#   emg: (25000,)
# 897
#   eeg: (25000,)
#   emg: (25000,)
# 898
#   eeg: (25000,)
#   emg: (25000,)
# 899
#   eeg: (25000,)
#   emg: (25000,)
# 9
#   eeg: (25000,)
#   emg: (25000,)
# 90
#   eeg: (25000,)
#   emg: (25000,)
# 900
#   eeg: (25000,)
#   emg: (25000,)
# 901
#   eeg: (25000,)
#   emg: (25000,)
# 902
#   eeg: (25000,)
#   emg: (25000,)
# 903
#   eeg: (25000,)
#   emg: (25000,)
# 904
#   eeg: (25000,)
#   emg: (25000,)
# 905
#   eeg: (25000,)
#   emg: (25000,)
# 906
#   eeg: (25000,)
#   emg: (25000,)
# 907
#   eeg: (25000,)
#   emg: (25000,)
# 908
#   eeg: (25000,)
#   emg: (25000,)
# 909
#   eeg: (25000,)
#   emg: (25000,)
# 91
#   eeg: (25000,)
#   emg: (25000,)
# 910
#   eeg: (25000,)
#   emg: (25000,)
# 911
#   eeg: (25000,)
#   emg: (25000,)
# 912
#   eeg: (25000,)
#   emg: (25000,)
# 913
#   eeg: (25000,)
#   emg: (25000,)
# 914
#   eeg: (25000,)
#   emg: (25000,)
# 915
#   eeg: (25000,)
#   emg: (25000,)
# 916
#   eeg: (25000,)
#   emg: (25000,)
# 917
#   eeg: (25000,)
#   emg: (25000,)
# 918
#   eeg: (25000,)
#   emg: (25000,)
# 919
#   eeg: (25000,)
#   emg: (25000,)
# 92
#   eeg: (25000,)
#   emg: (25000,)
# 920
#   eeg: (25000,)
#   emg: (25000,)
# 921
#   eeg: (25000,)
#   emg: (25000,)
# 922
#   eeg: (25000,)
#   emg: (25000,)
# 923
#   eeg: (25000,)
#   emg: (25000,)
# 924
#   eeg: (25000,)
#   emg: (25000,)
# 925
#   eeg: (25000,)
#   emg: (25000,)
# 926
#   eeg: (25000,)
#   emg: (25000,)
# 927
#   eeg: (25000,)
#   emg: (25000,)
# 928
#   eeg: (25000,)
#   emg: (25000,)
# 929
#   eeg: (25000,)
#   emg: (25000,)
# 93
#   eeg: (25000,)
#   emg: (25000,)
# 930
#   eeg: (25000,)
#   emg: (25000,)
# 931
#   eeg: (25000,)
#   emg: (25000,)
# 932
#   eeg: (25000,)
#   emg: (25000,)
# 933
#   eeg: (25000,)
#   emg: (25000,)
# 934
#   eeg: (25000,)
#   emg: (25000,)
# 935
#   eeg: (25000,)
#   emg: (25000,)
# 936
#   eeg: (25000,)
#   emg: (25000,)
# 937
#   eeg: (25000,)
#   emg: (25000,)
# 938
#   eeg: (25000,)
#   emg: (25000,)
# 939
#   eeg: (25000,)
#   emg: (25000,)
# 94
#   eeg: (25000,)
#   emg: (25000,)
# 940
#   eeg: (25000,)
#   emg: (25000,)
# 941
#   eeg: (25000,)
#   emg: (25000,)
# 942
#   eeg: (25000,)
#   emg: (25000,)
# 943
#   eeg: (25000,)
#   emg: (25000,)
# 944
#   eeg: (25000,)
#   emg: (25000,)
# 945
#   eeg: (25000,)
#   emg: (25000,)
# 946
#   eeg: (25000,)
#   emg: (25000,)
# 947
#   eeg: (25000,)
#   emg: (25000,)
# 948
#   eeg: (25000,)
#   emg: (25000,)
# 949
#   eeg: (25000,)
#   emg: (25000,)
# 95
#   eeg: (25000,)
#   emg: (25000,)
# 950
#   eeg: (25000,)
#   emg: (25000,)
# 951
#   eeg: (25000,)
#   emg: (25000,)
# 952
#   eeg: (25000,)
#   emg: (25000,)
# 953
#   eeg: (25000,)
#   emg: (25000,)
# 954
#   eeg: (25000,)
#   emg: (25000,)
# 955
#   eeg: (25000,)
#   emg: (25000,)
# 956
#   eeg: (25000,)
#   emg: (25000,)
# 957
#   eeg: (25000,)
#   emg: (25000,)
# 958
#   eeg: (25000,)
#   emg: (25000,)
# 959
#   eeg: (25000,)
#   emg: (25000,)
# 96
#   eeg: (25000,)
#   emg: (25000,)
# 960
#   eeg: (25000,)
#   emg: (25000,)
# 961
#   eeg: (25000,)
#   emg: (25000,)
# 962
#   eeg: (25000,)
#   emg: (25000,)
# 963
#   eeg: (25000,)
#   emg: (25000,)
# 964
#   eeg: (25000,)
#   emg: (25000,)
# 965
#   eeg: (25000,)
#   emg: (25000,)
# 966
#   eeg: (25000,)
#   emg: (25000,)
# 967
#   eeg: (25000,)
#   emg: (25000,)
# 968
#   eeg: (25000,)
#   emg: (25000,)
# 969
#   eeg: (25000,)
#   emg: (25000,)
# 97
#   eeg: (25000,)
#   emg: (25000,)
# 970
#   eeg: (25000,)
#   emg: (25000,)
# 971
#   eeg: (25000,)
#   emg: (25000,)
# 972
#   eeg: (25000,)
#   emg: (25000,)
# 973
#   eeg: (25000,)
#   emg: (25000,)
# 974
#   eeg: (25000,)
#   emg: (25000,)
# 975
#   eeg: (25000,)
#   emg: (25000,)
# 976
#   eeg: (25000,)
#   emg: (25000,)
# 977
#   eeg: (25000,)
#   emg: (25000,)
# 978
#   eeg: (25000,)
#   emg: (25000,)
# 979
#   eeg: (25000,)
#   emg: (25000,)
# 98
#   eeg: (25000,)
#   emg: (25000,)
# 980
#   eeg: (25000,)
#   emg: (25000,)
# 981
#   eeg: (25000,)
#   emg: (25000,)
# 982
#   eeg: (25000,)
#   emg: (25000,)
# 983
#   eeg: (25000,)
#   emg: (25000,)
# 984
#   eeg: (25000,)
#   emg: (25000,)
# 985
#   eeg: (25000,)
#   emg: (25000,)
# 986
#   eeg: (25000,)
#   emg: (25000,)
# 987
#   eeg: (25000,)
#   emg: (25000,)
# 988
#   eeg: (25000,)
#   emg: (25000,)
# 989
#   eeg: (25000,)
#   emg: (25000,)
# 99
#   eeg: (25000,)
#   emg: (25000,)
# 990
#   eeg: (25000,)
#   emg: (25000,)
# 991
#   eeg: (25000,)
#   emg: (25000,)
# 992
#   eeg: (25000,)
#   emg: (25000,)
# 993
#   eeg: (25000,)
#   emg: (25000,)
# 994
#   eeg: (25000,)
#   emg: (25000,)
# 995
#   eeg: (25000,)
#   emg: (25000,)
# 996
#   eeg: (25000,)
#   emg: (25000,)
# 997
#   eeg: (25000,)
#   emg: (25000,)
# 998
#   eeg: (25000,)
#   emg: (25000,)
# 999
#   eeg: (25000,)
#   emg: (25000,)
